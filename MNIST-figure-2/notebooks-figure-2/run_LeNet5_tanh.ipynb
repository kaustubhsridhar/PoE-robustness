# %% [markdown]
# # LeNet5 Tanh PGD

# %%
# %cd ../
# Out:
# /home/ksridhar/PoE_MNIST

# %%
import numpy as np
etas = [0.1, 0.01, 0.2, 0.02, 0.3, 0.4, 0.04, 0.5, 0.05, 0.6, 0.7, 0.07, 0.8, 0.08, 0.9, 0.14, 0.16, 0.28, 0.32, 0.56, 0.64, 1.0, 1.1, 1.2, 1.3, 1.4, 1.6, 1.12, 1.28, 2.0, 2.24, 2.56] + np.round(np.arange(1, 2, 0.07), 2).tolist() + np.round(np.arange(0.23, 1.7, 0.11), 2).tolist() + [0.00000005, 0.0000001, 0.000001, 0.00001, 0.0001, 0.001, 0.01, 0.02, 0.023]
print(etas)
# Out:
# [0.1, 0.01, 0.2, 0.02, 0.3, 0.4, 0.04, 0.5, 0.05, 0.6, 0.7, 0.07, 0.8, 0.08, 0.9, 0.14, 0.16, 0.28, 0.32, 0.56, 0.64, 1.0, 1.1, 1.2, 1.3, 1.4, 1.6, 1.12, 1.28, 2.0, 2.24, 2.56, 1.0, 1.07, 1.14, 1.21, 1.28, 1.35, 1.42, 1.49, 1.56, 1.63, 1.7, 1.77, 1.84, 1.91, 1.98, 0.23, 0.34, 0.45, 0.56, 0.67, 0.78, 0.89, 1.0, 1.11, 1.22, 1.33, 1.44, 1.55, 1.66, 5e-08, 1e-07, 1e-06, 1e-05, 0.0001, 0.001, 0.01, 0.02, 0.023]

# %%
for eta in etas:
    #eta = eta0 * (2**count)
    loc = "PGD/LeNet5_tanh_"+str(eta)
    # !python main.py -b 64 -n LeNet5 -a tanh -l $eta -g 1
    # !python adv_PGD.py -n LeNet5 -a tanh -l $eta -f $loc -g 1
    # !python main.py -b 64 -n LeNet5 -a tanh -l $eta -r2 -f $loc -g 1
# Out:
# 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.31, err 0.94 | val loss 2.31, err 0.95 | adv loss 2.36, err 1.00
# ep 2/10: train loss 2.30, err 0.91 | val loss 2.31, err 0.94 | adv loss 2.36, err 1.00
# ep 3/10: train loss 2.30, err 0.84 | val loss 2.30, err 0.94 | adv loss 2.36, err 1.00
# ep 4/10: train loss 2.31, err 0.94 | val loss 2.30, err 0.94 | adv loss 2.36, err 1.00
# ep 5/10: train loss 2.31, err 1.00 | val loss 2.30, err 0.94 | adv loss 2.36, err 1.00
# ep 6/10: train loss 2.32, err 0.97 | val loss 2.30, err 0.94 | adv loss 2.36, err 1.00
# ep 7/10: train loss 2.30, err 0.97 | val loss 2.30, err 0.94 | adv loss 2.36, err 1.00
# ep 8/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.94 | adv loss 2.36, err 1.00
# ep 9/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.94 | adv loss 2.36, err 1.00
# ep 10/10: train loss 2.29, err 0.94 | val loss 2.30, err 0.94 | adv loss 2.36, err 1.00
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
#
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 0.0001, round -> <class 'int'> : 1
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.31, err 0.94 | val loss 2.30, err 0.94 | adv loss -1.00, err -1.00
# ep 2/10: train loss 2.31, err 1.00 | val loss 2.30, err 0.94 | adv loss -1.00, err -1.00
# ep 3/10: train loss 2.29, err 0.81 | val loss 2.30, err 0.93 | adv loss -1.00, err -1.00
# ep 4/10: train loss 2.30, err 0.88 | val loss 2.30, err 0.92 | adv loss -1.00, err -1.00
# ep 5/10: train loss 2.29, err 0.91 | val loss 2.30, err 0.91 | adv loss -1.00, err -1.00
# ep 6/10: train loss 2.29, err 0.75 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 7/10: train loss 2.29, err 0.84 | val loss 2.30, err 0.89 | adv loss -1.00, err -1.00
# ep 8/10: train loss 2.30, err 0.84 | val loss 2.30, err 0.87 | adv loss -1.00, err -1.00
# ep 9/10: train loss 2.31, err 0.91 | val loss 2.30, err 0.87 | adv loss -1.00, err -1.00
# ep 10/10: train loss 2.30, err 0.84 | val loss 2.30, err 0.86 | adv loss -1.00, err -1.00
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
# network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 0.0001, adv_folder-> <class 'str'> : PGD/LeNet5_tanh_0.0001
# cuda:1
# loading model at ./model_statedicts/mnist_LeNet5_tanh_0.0001.pth
# ==> full_val has 10000 images
# l:  (8000, 1, 28, 28) (8000,)
# l2:  torch.Size([8000, 1, 28, 28]) torch.Size([8000])
# mkdir: cannot create directory ‘./PGD’: File exists
#  Progress 8000 / 8000
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 0.0001, round -> <class 'int'> : 2
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.31, err 0.94 | val loss 2.30, err 0.94 | adv loss 2.36, err 1.00
# ep 2/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.94 | adv loss 2.36, err 1.00
# ep 3/10: train loss 2.30, err 0.84 | val loss 2.30, err 0.93 | adv loss 2.36, err 1.00
# ep 4/10: train loss 2.30, err 0.84 | val loss 2.30, err 0.92 | adv loss 2.36, err 1.00
# ep 5/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.91 | adv loss 2.36, err 1.00
# ep 6/10: train loss 2.31, err 0.94 | val loss 2.30, err 0.90 | adv loss 2.36, err 1.00
# ep 7/10: train loss 2.29, err 0.91 | val loss 2.30, err 0.89 | adv loss 2.36, err 1.00
# ep 8/10: train loss 2.29, err 0.88 | val loss 2.30, err 0.87 | adv loss 2.36, err 1.00
# ep 9/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.87 | adv loss 2.36, err 1.00
# ep 10/10: train loss 2.29, err 0.75 | val loss 2.30, err 0.86 | adv loss 2.36, err 1.00
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
#
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 0.001, round -> <class 'int'> : 1
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.86 | adv loss -1.00, err -1.00
# ep 2/10: train loss 2.29, err 0.88 | val loss 2.29, err 0.82 | adv loss -1.00, err -1.00
# ep 3/10: train loss 2.27, err 0.72 | val loss 2.27, err 0.77 | adv loss -1.00, err -1.00
# ep 4/10: train loss 2.27, err 0.78 | val loss 2.25, err 0.70 | adv loss -1.00, err -1.00
# ep 5/10: train loss 2.19, err 0.44 | val loss 2.22, err 0.58 | adv loss -1.00, err -1.00
# ep 6/10: train loss 2.14, err 0.41 | val loss 2.15, err 0.48 | adv loss -1.00, err -1.00
# ep 7/10: train loss 2.01, err 0.38 | val loss 2.05, err 0.42 | adv loss -1.00, err -1.00
# ep 8/10: train loss 1.92, err 0.31 | val loss 1.93, err 0.37 | adv loss -1.00, err -1.00
# ep 9/10: train loss 1.79, err 0.34 | val loss 1.80, err 0.32 | adv loss -1.00, err -1.00
# ep 10/10: train loss 1.73, err 0.34 | val loss 1.70, err 0.27 | adv loss -1.00, err -1.00
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
# network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 0.001, adv_folder-> <class 'str'> : PGD/LeNet5_tanh_0.001
# cuda:1
# loading model at ./model_statedicts/mnist_LeNet5_tanh_0.001.pth
# ==> full_val has 10000 images
# l:  (8000, 1, 28, 28) (8000,)
# l2:  torch.Size([8000, 1, 28, 28]) torch.Size([8000])
# mkdir: cannot create directory ‘./PGD’: File exists
#  Progress 8000 / 8000
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 0.001, round -> <class 'int'> : 2
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.86 | adv loss 2.31, err 0.93
# ep 2/10: train loss 2.28, err 0.72 | val loss 2.29, err 0.83 | adv loss 2.31, err 0.89
# ep 3/10: train loss 2.28, err 0.75 | val loss 2.27, err 0.77 | adv loss 2.31, err 0.86
# ep 4/10: train loss 2.25, err 0.66 | val loss 2.25, err 0.70 | adv loss 2.30, err 0.83
# ep 5/10: train loss 2.20, err 0.53 | val loss 2.22, err 0.57 | adv loss 2.29, err 0.81
# ep 6/10: train loss 2.16, err 0.50 | val loss 2.15, err 0.47 | adv loss 2.28, err 0.81
# ep 7/10: train loss 2.07, err 0.47 | val loss 2.05, err 0.42 | adv loss 2.24, err 0.81
# ep 8/10: train loss 1.95, err 0.44 | val loss 1.93, err 0.37 | adv loss 2.21, err 0.80
# ep 9/10: train loss 1.85, err 0.28 | val loss 1.80, err 0.32 | adv loss 2.18, err 0.80
# ep 10/10: train loss 1.74, err 0.41 | val loss 1.70, err 0.27 | adv loss 2.16, err 0.79
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
#
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 0.01, round -> <class 'int'> : 1
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 1.77, err 0.38 | val loss 1.70, err 0.27 | adv loss -1.00, err -1.00
# ep 2/10: train loss 1.15, err 0.06 | val loss 1.21, err 0.13 | adv loss -1.00, err -1.00
# ep 3/10: train loss 1.05, err 0.09 | val loss 1.07, err 0.11 | adv loss -1.00, err -1.00
# ep 4/10: train loss 1.09, err 0.19 | val loss 1.01, err 0.09 | adv loss -1.00, err -1.00
# ep 5/10: train loss 0.95, err 0.06 | val loss 0.97, err 0.06 | adv loss -1.00, err -1.00
# ep 6/10: train loss 0.99, err 0.16 | val loss 0.94, err 0.05 | adv loss -1.00, err -1.00
# ep 7/10: train loss 0.91, err 0.06 | val loss 0.92, err 0.04 | adv loss -1.00, err -1.00
# ep 8/10: train loss 0.87, err 0.00 | val loss 0.90, err 0.04 | adv loss -1.00, err -1.00
# ep 9/10: train loss 0.85, err 0.00 | val loss 0.89, err 0.04 | adv loss -1.00, err -1.00
# ep 10/10: train loss 0.89, err 0.03 | val loss 0.88, err 0.04 | adv loss -1.00, err -1.00
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
# network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 0.01, adv_folder-> <class 'str'> : PGD/LeNet5_tanh_0.01
# cuda:1
# loading model at ./model_statedicts/mnist_LeNet5_tanh_0.01.pth
# ==> full_val has 10000 images
# l:  (8000, 1, 28, 28) (8000,)
# l2:  torch.Size([8000, 1, 28, 28]) torch.Size([8000])
# mkdir: cannot create directory ‘./PGD’: File exists
# mkdir: cannot create directory ‘PGD/LeNet5_tanh_0.01’: File exists
# mkdir: cannot create directory ‘0000’: File exists
# mkdir: cannot create directory ‘0001’: File exists
# mkdir: cannot create directory ‘0002’: File exists
# mkdir: cannot create directory ‘0003’: File exists
# mkdir: cannot create directory ‘0004’: File exists
# mkdir: cannot create directory ‘0005’: File exists
# mkdir: cannot create directory ‘0006’: File exists
# mkdir: cannot create directory ‘0007’: File exists
# mkdir: cannot create directory ‘0008’: File exists
# mkdir: cannot create directory ‘0009’: File exists
#  Progress 8000 / 8000
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 0.01, round -> <class 'int'> : 2
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 1.77, err 0.38 | val loss 1.70, err 0.27 | adv loss 1.94, err 0.54
# ep 2/10: train loss 1.23, err 0.09 | val loss 1.21, err 0.13 | adv loss 1.91, err 0.70
# ep 3/10: train loss 1.11, err 0.09 | val loss 1.07, err 0.11 | adv loss 1.98, err 0.74
# ep 4/10: train loss 0.97, err 0.12 | val loss 1.01, err 0.08 | adv loss 2.08, err 0.78
# ep 5/10: train loss 0.98, err 0.06 | val loss 0.97, err 0.06 | adv loss 2.17, err 0.79
# ep 6/10: train loss 0.87, err 0.03 | val loss 0.94, err 0.05 | adv loss 2.22, err 0.80
# ep 7/10: train loss 0.89, err 0.06 | val loss 0.92, err 0.04 | adv loss 2.27, err 0.80
# ep 8/10: train loss 0.88, err 0.03 | val loss 0.90, err 0.04 | adv loss 2.29, err 0.80
# ep 9/10: train loss 0.88, err 0.03 | val loss 0.89, err 0.04 | adv loss 2.30, err 0.80
# ep 10/10: train loss 0.91, err 0.06 | val loss 0.88, err 0.04 | adv loss 2.33, err 0.80
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
#
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 0.02, round -> <class 'int'> : 1
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 1.25, err 0.25 | val loss 1.21, err 0.13 | adv loss -1.00, err -1.00
# ep 2/10: train loss 0.97, err 0.03 | val loss 1.01, err 0.09 | adv loss -1.00, err -1.00
# ep 3/10: train loss 0.91, err 0.00 | val loss 0.94, err 0.05 | adv loss -1.00, err -1.00
# ep 4/10: train loss 0.95, err 0.06 | val loss 0.90, err 0.04 | adv loss -1.00, err -1.00
# ep 5/10: train loss 0.85, err 0.03 | val loss 0.88, err 0.04 | adv loss -1.00, err -1.00
# ep 6/10: train loss 0.94, err 0.16 | val loss 0.87, err 0.03 | adv loss -1.00, err -1.00
# ep 7/10: train loss 0.85, err 0.03 | val loss 0.86, err 0.03 | adv loss -1.00, err -1.00
# ep 8/10: train loss 0.83, err 0.00 | val loss 0.86, err 0.03 | adv loss -1.00, err -1.00
# ep 9/10: train loss 0.83, err 0.00 | val loss 0.85, err 0.02 | adv loss -1.00, err -1.00
# ep 10/10: train loss 0.87, err 0.03 | val loss 0.85, err 0.02 | adv loss -1.00, err -1.00
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
# network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 0.02, adv_folder-> <class 'str'> : PGD/LeNet5_tanh_0.02
# cuda:1
# loading model at ./model_statedicts/mnist_LeNet5_tanh_0.02.pth
# ==> full_val has 10000 images
# l:  (8000, 1, 28, 28) (8000,)
# l2:  torch.Size([8000, 1, 28, 28]) torch.Size([8000])
# mkdir: cannot create directory ‘./PGD’: File exists
# mkdir: cannot create directory ‘PGD/LeNet5_tanh_0.02’: File exists
# mkdir: cannot create directory ‘0000’: File exists
# mkdir: cannot create directory ‘0001’: File exists
# mkdir: cannot create directory ‘0002’: File exists
# mkdir: cannot create directory ‘0003’: File exists
# mkdir: cannot create directory ‘0004’: File exists
# mkdir: cannot create directory ‘0005’: File exists
# mkdir: cannot create directory ‘0006’: File exists
# mkdir: cannot create directory ‘0007’: File exists
# mkdir: cannot create directory ‘0008’: File exists
# mkdir: cannot create directory ‘0009’: File exists
#  Progress 8000 / 8000
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 0.02, round -> <class 'int'> : 2
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 1.25, err 0.25 | val loss 1.21, err 0.13 | adv loss 1.78, err 0.60
# ep 2/10: train loss 0.99, err 0.06 | val loss 1.01, err 0.09 | adv loss 1.86, err 0.71
# ep 3/10: train loss 0.93, err 0.00 | val loss 0.94, err 0.05 | adv loss 2.06, err 0.76
# ep 4/10: train loss 0.89, err 0.06 | val loss 0.90, err 0.04 | adv loss 2.17, err 0.78
# ep 5/10: train loss 0.93, err 0.06 | val loss 0.88, err 0.04 | adv loss 2.25, err 0.79
# ep 6/10: train loss 0.82, err 0.00 | val loss 0.87, err 0.03 | adv loss 2.29, err 0.79
# ep 7/10: train loss 0.86, err 0.06 | val loss 0.86, err 0.03 | adv loss 2.34, err 0.80
# ep 8/10: train loss 0.85, err 0.03 | val loss 0.86, err 0.03 | adv loss 2.37, err 0.80
# ep 9/10: train loss 0.84, err 0.00 | val loss 0.85, err 0.02 | adv loss 2.38, err 0.80
# ep 10/10: train loss 0.88, err 0.03 | val loss 0.85, err 0.02 | adv loss 2.40, err 0.80
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
#
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 0.023, round -> <class 'int'> : 1
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 1.20, err 0.28 | val loss 1.15, err 0.12 | adv loss -1.00, err -1.00
# ep 2/10: train loss 0.94, err 0.03 | val loss 0.98, err 0.07 | adv loss -1.00, err -1.00
# ep 3/10: train loss 0.89, err 0.00 | val loss 0.92, err 0.04 | adv loss -1.00, err -1.00
# ep 4/10: train loss 0.93, err 0.06 | val loss 0.89, err 0.04 | adv loss -1.00, err -1.00
# ep 5/10: train loss 0.84, err 0.03 | val loss 0.87, err 0.03 | adv loss -1.00, err -1.00
# ep 6/10: train loss 0.93, err 0.12 | val loss 0.86, err 0.03 | adv loss -1.00, err -1.00
# ep 7/10: train loss 0.85, err 0.03 | val loss 0.86, err 0.03 | adv loss -1.00, err -1.00
# ep 8/10: train loss 0.82, err 0.00 | val loss 0.85, err 0.02 | adv loss -1.00, err -1.00
# ep 9/10: train loss 0.82, err 0.00 | val loss 0.85, err 0.02 | adv loss -1.00, err -1.00
# ep 10/10: train loss 0.86, err 0.03 | val loss 0.84, err 0.02 | adv loss -1.00, err -1.00
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
# network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 0.023, adv_folder-> <class 'str'> : PGD/LeNet5_tanh_0.023
# cuda:1
# loading model at ./model_statedicts/mnist_LeNet5_tanh_0.023.pth
# ==> full_val has 10000 images
# l:  (8000, 1, 28, 28) (8000,)
# l2:  torch.Size([8000, 1, 28, 28]) torch.Size([8000])
# mkdir: cannot create directory ‘./PGD’: File exists
#  Progress 8000 / 8000
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 0.023, round -> <class 'int'> : 2
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 1.20, err 0.28 | val loss 1.15, err 0.12 | adv loss 1.74, err 0.60
# ep 2/10: train loss 0.97, err 0.06 | val loss 0.98, err 0.07 | adv loss 1.89, err 0.72
# ep 3/10: train loss 0.91, err 0.00 | val loss 0.92, err 0.04 | adv loss 2.07, err 0.76
# ep 4/10: train loss 0.88, err 0.06 | val loss 0.89, err 0.04 | adv loss 2.19, err 0.79
# ep 5/10: train loss 0.93, err 0.06 | val loss 0.87, err 0.03 | adv loss 2.26, err 0.79
# ep 6/10: train loss 0.81, err 0.00 | val loss 0.86, err 0.03 | adv loss 2.30, err 0.79
# ep 7/10: train loss 0.85, err 0.06 | val loss 0.86, err 0.03 | adv loss 2.35, err 0.80
# ep 8/10: train loss 0.84, err 0.03 | val loss 0.85, err 0.03 | adv loss 2.38, err 0.80
# ep 9/10: train loss 0.83, err 0.00 | val loss 0.85, err 0.02 | adv loss 2.39, err 0.80
# ep 10/10: train loss 0.88, err 0.03 | val loss 0.84, err 0.02 | adv loss 2.41, err 0.80
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists

# %%
more_etas = np.round(np.arange(1.8, 3.0, 0.1), 2).tolist()
for eta in more_etas:
    #eta = eta0 * (2**count)
    loc = "PGD/LeNet5_tanh_"+str(eta)
    # !python main.py -b 64 -n LeNet5 -a tanh -l $eta -g 1
    # !python adv_PGD.py -n LeNet5 -a tanh -l $eta -f $loc -g 1
    # !python main.py -b 64 -n LeNet5 -a tanh -l $eta -r2 -f $loc -g 1
# Out:
# rain loss 0.81, err 0.00 | val loss 0.84, err 0.02 | adv loss -1.00, err -1.00
# ep 10/10: train loss 0.88, err 0.03 | val loss 0.85, err 0.03 | adv loss -1.00, err -1.00
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
# network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 2.4, adv_folder-> <class 'str'> : PGD/LeNet5_tanh_2.4
# cuda:1
# loading model at ./model_statedicts/mnist_LeNet5_tanh_2.4.pth
# ==> full_val has 10000 images
# l:  (8000, 1, 28, 28) (8000,)
# l2:  torch.Size([8000, 1, 28, 28]) torch.Size([8000])
# mkdir: cannot create directory ‘./PGD’: File exists
#  Progress 8000 / 8000
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 2.4, round -> <class 'int'> : 2
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 0.87, err 0.03 | val loss 0.87, err 0.04 | adv loss 1.48, err 0.38
# ep 2/10: train loss 0.86, err 0.03 | val loss 0.89, err 0.06 | adv loss 1.61, err 0.52
# ep 3/10: train loss 0.82, err 0.03 | val loss 0.85, err 0.03 | adv loss 1.63, err 0.46
# ep 4/10: train loss 0.94, err 0.09 | val loss 0.85, err 0.03 | adv loss 1.60, err 0.46
# ep 5/10: train loss 0.82, err 0.00 | val loss 0.86, err 0.04 | adv loss 0.98, err 0.11
# ep 6/10: train loss 0.80, err 0.00 | val loss 0.85, err 0.03 | adv loss 1.08, err 0.17
# ep 7/10: train loss 0.82, err 0.03 | val loss 0.84, err 0.02 | adv loss 1.00, err 0.12
# ep 8/10: train loss 0.89, err 0.03 | val loss 0.85, err 0.03 | adv loss 2.04, err 0.66
# ep 9/10: train loss 0.82, err 0.03 | val loss 0.84, err 0.03 | adv loss 1.21, err 0.24
# ep 10/10: train loss 0.82, err 0.00 | val loss 0.85, err 0.03 | adv loss 1.50, err 0.39
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
#
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 2.5, round -> <class 'int'> : 1
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 0.89, err 0.03 | val loss 0.85, err 0.03 | adv loss -1.00, err -1.00
# ep 2/10: train loss 0.88, err 0.03 | val loss 0.85, err 0.03 | adv loss -1.00, err -1.00
# ep 3/10: train loss 0.80, err 0.00 | val loss 0.84, err 0.03 | adv loss -1.00, err -1.00
# ep 4/10: train loss 0.87, err 0.06 | val loss 0.84, err 0.03 | adv loss -1.00, err -1.00
# ep 5/10: train loss 0.80, err 0.00 | val loss 0.85, err 0.03 | adv loss -1.00, err -1.00
# ep 6/10: train loss 0.83, err 0.03 | val loss 0.85, err 0.03 | adv loss -1.00, err -1.00
# ep 7/10: train loss 0.82, err 0.00 | val loss 0.84, err 0.03 | adv loss -1.00, err -1.00
# ep 8/10: train loss 0.87, err 0.03 | val loss 0.86, err 0.04 | adv loss -1.00, err -1.00
# ep 9/10: train loss 0.82, err 0.00 | val loss 0.84, err 0.02 | adv loss -1.00, err -1.00
# ep 10/10: train loss 0.86, err 0.03 | val loss 0.84, err 0.03 | adv loss -1.00, err -1.00
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
# network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 2.5, adv_folder-> <class 'str'> : PGD/LeNet5_tanh_2.5
# cuda:1
# loading model at ./model_statedicts/mnist_LeNet5_tanh_2.5.pth
# ==> full_val has 10000 images
# l:  (8000, 1, 28, 28) (8000,)
# l2:  torch.Size([8000, 1, 28, 28]) torch.Size([8000])
# mkdir: cannot create directory ‘./PGD’: File exists
#  Progress 8000 / 8000
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 2.5, round -> <class 'int'> : 2
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.52, err 0.94 | val loss 2.40, err 0.90 | adv loss 2.41, err 0.90
# ep 2/10: train loss 2.27, err 0.91 | val loss 2.40, err 0.90 | adv loss 2.41, err 0.90
# ep 3/10: train loss 2.46, err 0.81 | val loss 2.40, err 0.90 | adv loss 2.41, err 0.90
# ep 4/10: train loss 2.34, err 0.84 | val loss 2.40, err 0.90 | adv loss 2.41, err 0.90
# ep 5/10: train loss 2.40, err 0.91 | val loss 2.40, err 0.90 | adv loss 2.41, err 0.90
# ep 6/10: train loss 2.40, err 0.91 | val loss 2.40, err 0.90 | adv loss 2.41, err 0.90
# ep 7/10: train loss 2.52, err 0.91 | val loss 2.40, err 0.90 | adv loss 2.41, err 0.90
# ep 8/10: train loss 2.46, err 0.91 | val loss 2.40, err 0.90 | adv loss 2.41, err 0.90
# ep 9/10: train loss 2.40, err 0.94 | val loss 2.40, err 0.90 | adv loss 2.41, err 0.90
# ep 10/10: train loss 2.40, err 0.91 | val loss 2.40, err 0.90 | adv loss 2.41, err 0.90
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
#
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 2.6, round -> <class 'int'> : 1
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.87, err 0.97 | val loss 2.81, err 0.91 | adv loss -1.00, err -1.00
# ep 2/10: train loss 2.56, err 0.91 | val loss 2.62, err 0.90 | adv loss -1.00, err -1.00
# ep 3/10: train loss 2.94, err 0.88 | val loss 2.63, err 0.90 | adv loss -1.00, err -1.00
# ep 4/10: train loss 2.63, err 0.84 | val loss 2.69, err 0.90 | adv loss -1.00, err -1.00
# ep 5/10: train loss 2.63, err 1.00 | val loss 2.62, err 0.90 | adv loss -1.00, err -1.00
# ep 6/10: train loss 2.81, err 0.88 | val loss 2.62, err 0.90 | adv loss -1.00, err -1.00
# ep 7/10: train loss 2.81, err 0.94 | val loss 2.62, err 0.90 | adv loss -1.00, err -1.00
# ep 8/10: train loss 2.88, err 0.84 | val loss 2.62, err 0.90 | adv loss -1.00, err -1.00
# ep 9/10: train loss 2.69, err 0.91 | val loss 2.62, err 0.90 | adv loss -1.00, err -1.00
# ep 10/10: train loss 2.94, err 0.94 | val loss 2.62, err 0.90 | adv loss -1.00, err -1.00
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
# network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 2.6, adv_folder-> <class 'str'> : PGD/LeNet5_tanh_2.6
# cuda:1
# loading model at ./model_statedicts/mnist_LeNet5_tanh_2.6.pth
# ==> full_val has 10000 images
# l:  (8000, 1, 28, 28) (8000,)
# l2:  torch.Size([8000, 1, 28, 28]) torch.Size([8000])
# mkdir: cannot create directory ‘./PGD’: File exists
#  Progress 8000 / 8000
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 2.6, round -> <class 'int'> : 2
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.44, err 0.94 | val loss 2.61, err 0.89 | adv loss 2.60, err 0.90
# ep 2/10: train loss 2.34, err 0.75 | val loss 2.41, err 0.89 | adv loss 2.41, err 0.90
# ep 3/10: train loss 2.52, err 0.97 | val loss 2.41, err 0.89 | adv loss 2.41, err 0.90
# ep 4/10: train loss 2.27, err 0.88 | val loss 2.41, err 0.89 | adv loss 2.41, err 0.90
# ep 5/10: train loss 2.27, err 0.81 | val loss 2.41, err 0.89 | adv loss 2.41, err 0.90
# ep 6/10: train loss 2.34, err 0.91 | val loss 2.41, err 0.89 | adv loss 2.41, err 0.90
# ep 7/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.89 | adv loss 2.30, err 0.90
# ep 8/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.89 | adv loss 2.30, err 0.90
# ep 9/10: train loss 2.30, err 0.97 | val loss 2.30, err 0.89 | adv loss 2.30, err 0.90
# ep 10/10: train loss 2.30, err 0.78 | val loss 2.30, err 0.89 | adv loss 2.30, err 0.90
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
#
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 2.7, round -> <class 'int'> : 1
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 0.84, err 0.03 | val loss 0.86, err 0.04 | adv loss -1.00, err -1.00
# ep 2/10: train loss 0.88, err 0.06 | val loss 0.88, err 0.05 | adv loss -1.00, err -1.00
# ep 3/10: train loss 0.84, err 0.03 | val loss 0.86, err 0.04 | adv loss -1.00, err -1.00
# ep 4/10: train loss 0.87, err 0.03 | val loss 0.85, err 0.03 | adv loss -1.00, err -1.00
# ep 5/10: train loss 0.87, err 0.03 | val loss 0.86, err 0.04 | adv loss -1.00, err -1.00
# ep 6/10: train loss 0.90, err 0.06 | val loss 0.86, err 0.03 | adv loss -1.00, err -1.00
# ep 7/10: train loss 0.80, err 0.00 | val loss 0.84, err 0.03 | adv loss -1.00, err -1.00
# ep 8/10: train loss 0.80, err 0.00 | val loss 0.86, err 0.03 | adv loss -1.00, err -1.00
# ep 9/10: train loss 0.81, err 0.00 | val loss 0.85, err 0.03 | adv loss -1.00, err -1.00
# ep 10/10: train loss 0.89, err 0.03 | val loss 0.86, err 0.03 | adv loss -1.00, err -1.00
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
# network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 2.7, adv_folder-> <class 'str'> : PGD/LeNet5_tanh_2.7
# cuda:1
# loading model at ./model_statedicts/mnist_LeNet5_tanh_2.7.pth
# ==> full_val has 10000 images
# l:  (8000, 1, 28, 28) (8000,)
# l2:  torch.Size([8000, 1, 28, 28]) torch.Size([8000])
# mkdir: cannot create directory ‘./PGD’: File exists
#  Progress 8000 / 8000
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 2.7, round -> <class 'int'> : 2
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.63, err 0.84 | val loss 2.58, err 0.90 | adv loss 2.60, err 0.90
# ep 2/10: train loss 2.31, err 0.94 | val loss 2.58, err 0.90 | adv loss 2.60, err 0.90
# ep 3/10: train loss 2.63, err 0.84 | val loss 2.58, err 0.90 | adv loss 2.60, err 0.90
# ep 4/10: train loss 2.69, err 0.97 | val loss 2.58, err 0.90 | adv loss 2.60, err 0.90
# ep 5/10: train loss 2.50, err 0.97 | val loss 2.58, err 0.90 | adv loss 2.60, err 0.90
# ep 6/10: train loss 2.63, err 0.94 | val loss 2.58, err 0.90 | adv loss 2.60, err 0.90
# ep 7/10: train loss 2.44, err 0.97 | val loss 2.58, err 0.90 | adv loss 2.60, err 0.90
# ep 8/10: train loss 2.50, err 0.91 | val loss 2.58, err 0.90 | adv loss 2.60, err 0.90
# ep 9/10: train loss 2.63, err 0.75 | val loss 2.58, err 0.90 | adv loss 2.60, err 0.90
# ep 10/10: train loss 2.44, err 0.88 | val loss 2.58, err 0.90 | adv loss 2.60, err 0.90
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
#
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 2.8, round -> <class 'int'> : 1
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.34, err 0.94 | val loss 2.44, err 0.90 | adv loss -1.00, err -1.00
# ep 2/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 3/10: train loss 2.30, err 0.88 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 4/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 5/10: train loss 2.30, err 0.81 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 6/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 7/10: train loss 2.30, err 0.88 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 8/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 9/10: train loss 2.30, err 0.88 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 10/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
# network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 2.8, adv_folder-> <class 'str'> : PGD/LeNet5_tanh_2.8
# cuda:1
# loading model at ./model_statedicts/mnist_LeNet5_tanh_2.8.pth
# ==> full_val has 10000 images
# l:  (8000, 1, 28, 28) (8000,)
# l2:  torch.Size([8000, 1, 28, 28]) torch.Size([8000])
# mkdir: cannot create directory ‘./PGD’: File exists
#  Progress 8000 / 8000
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 2.8, round -> <class 'int'> : 2
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.74, err 0.94 | val loss 2.50, err 0.90 | adv loss 2.51, err 0.90
# ep 2/10: train loss 2.49, err 0.91 | val loss 2.50, err 0.90 | adv loss 2.51, err 0.90
# ep 3/10: train loss 2.43, err 0.81 | val loss 2.50, err 0.90 | adv loss 2.51, err 0.90
# ep 4/10: train loss 2.36, err 0.84 | val loss 2.50, err 0.90 | adv loss 2.51, err 0.90
# ep 5/10: train loss 2.49, err 0.91 | val loss 2.50, err 0.90 | adv loss 2.51, err 0.90
# ep 6/10: train loss 2.43, err 0.91 | val loss 2.50, err 0.90 | adv loss 2.51, err 0.90
# ep 7/10: train loss 2.68, err 0.91 | val loss 2.50, err 0.90 | adv loss 2.51, err 0.90
# ep 8/10: train loss 2.61, err 0.91 | val loss 2.50, err 0.90 | adv loss 2.51, err 0.90
# ep 9/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.90 | adv loss 2.30, err 0.90
# ep 10/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.90 | adv loss 2.30, err 0.90
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
#
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 2.9, round -> <class 'int'> : 1
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 2/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 3/10: train loss 2.30, err 0.88 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 4/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 5/10: train loss 2.30, err 0.81 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 6/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 7/10: train loss 2.30, err 0.88 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 8/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 9/10: train loss 2.30, err 0.88 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 10/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
# network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 2.9, adv_folder-> <class 'str'> : PGD/LeNet5_tanh_2.9
# cuda:1
# loading model at ./model_statedicts/mnist_LeNet5_tanh_2.9.pth
# ==> full_val has 10000 images
# l:  (8000, 1, 28, 28) (8000,)
# l2:  torch.Size([8000, 1, 28, 28]) torch.Size([8000])
# mkdir: cannot create directory ‘./PGD’: File exists
#  Progress 8000 / 8000
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : tanh, learning_rate -> <class 'float'> : 2.9, round -> <class 'int'> : 2
# cuda:1
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.90 | adv loss 2.30, err 0.90
# ep 2/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.90 | adv loss 2.30, err 0.90
# ep 3/10: train loss 2.30, err 0.81 | val loss 2.30, err 0.90 | adv loss 2.30, err 0.90
# ep 4/10: train loss 2.30, err 0.84 | val loss 2.30, err 0.90 | adv loss 2.30, err 0.90
# ep 5/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.90 | adv loss 2.30, err 0.90
# ep 6/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.90 | adv loss 2.30, err 0.90
# ep 7/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.90 | adv loss 2.30, err 0.90
# ep 8/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.90 | adv loss 2.30, err 0.90
# ep 9/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.90 | adv loss 2.30, err 0.90
# ep 10/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.90 | adv loss 2.30, err 0.90
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists

# %%
# PGD tanh plot
import numpy as np
from plot import lr_plot

unsorted_etas = [0.1, 0.01, 0.2, 0.02, 0.3, 0.4, 0.04, 0.5, 0.05, 0.6, 0.7, 0.07, 0.8, 0.08, 0.9, 0.14, 0.16, 0.28, 0.32, 0.56, 0.64, 1.0, 1.1, 1.2, 1.3, 1.4, 1.6, 1.12, 1.28, 2.0, 2.24, 2.56] + np.round(np.arange(1, 2, 0.07), 2).tolist() + [0.00000005, 0.0000001, 0.000001, 0.00001, 0.0001, 0.001, 0.023] + np.round(np.arange(0.23, 1.7, 0.11), 2).tolist() + [0.00000005, 0.0000001, 0.000001, 0.00001, 0.0001, 0.001, 0.01, 0.02, 0.023] + np.round(np.arange(1.8, 3.0, 0.1), 2).tolist()

etas = sorted(unsorted_etas, reverse=False)
list = []
for eta in etas:
    list.append("PGD/LeNet5_tanh_{}".format(eta))
lr_plot(list, etas)

# %%
from plot import get_adv_err, get_val_err
print(etas)
print('2/L: val acc {} | adv acc {}'.format(1-get_val_err('PGD/LeNet5_tanh_2.4'), 1-get_adv_err('PGD/LeNet5_tanh_2.4')))
print('1/L: val acc {} | adv acc {}'.format(1-get_val_err('PGD/LeNet5_tanh_1.2'), 1-get_adv_err('PGD/LeNet5_tanh_1.2')))
# Out:
# [5e-08, 5e-08, 1e-07, 1e-07, 1e-06, 1e-06, 1e-05, 1e-05, 0.0001, 0.0001, 0.001, 0.001, 0.01, 0.01, 0.02, 0.02, 0.023, 0.023, 0.04, 0.05, 0.07, 0.08, 0.1, 0.14, 0.16, 0.2, 0.23, 0.28, 0.3, 0.32, 0.34, 0.4, 0.45, 0.5, 0.56, 0.56, 0.6, 0.64, 0.67, 0.7, 0.78, 0.8, 0.89, 0.9, 1.0, 1.0, 1.0, 1.07, 1.1, 1.11, 1.12, 1.14, 1.2, 1.21, 1.22, 1.28, 1.28, 1.3, 1.33, 1.35, 1.4, 1.42, 1.44, 1.49, 1.55, 1.56, 1.6, 1.63, 1.66, 1.7, 1.77, 1.8, 1.84, 1.9, 1.91, 1.98, 2.0, 2.0, 2.1, 2.2, 2.24, 2.3, 2.4, 2.5, 2.56, 2.6, 2.7, 2.8, 2.9]
# 2/L: val acc 0.9694000016897917 | adv acc 0.6107499897480011
# 1/L: val acc 0.9875000007450581 | adv acc 0.6959999799728394
