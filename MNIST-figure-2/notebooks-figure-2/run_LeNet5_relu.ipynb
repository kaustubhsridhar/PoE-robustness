# %% [markdown]
# # LeNet5 Relu PGD

# %%
# %cd ../
# Out:
# /home/ksridhar/PoE_MNIST

# %%
import numpy as np
etas = [0.1, 0.01, 0.2, 0.02, 0.3, 0.4, 0.04, 0.5, 0.05, 0.6, 0.7, 0.007, 0.8, 0.08, 0.9, 0.014, 0.16, 0.028, 0.32, 0.0035, 0.056, 0.64, 0.112, 0.224, 0.448, 1.0, 1.1, 1.2, 1.3, 1.4, 1.6, 1.28, 2.0, 2.56] + np.round(np.arange(0.15, 0.5, 0.018), 2).tolist() + np.round(np.arange(0.03, 0.7, 0.06), 2).tolist() + [0.00000005, 0.0000001, 0.000001, 0.00001, 0.0001, 0.001, 0.01, 0.02, 0.023]
print(etas)
# Out:
# [0.1, 0.01, 0.2, 0.02, 0.3, 0.4, 0.04, 0.5, 0.05, 0.6, 0.7, 0.007, 0.8, 0.08, 0.9, 0.014, 0.16, 0.028, 0.32, 0.0035, 0.056, 0.64, 0.112, 0.224, 0.448, 1.0, 1.1, 1.2, 1.3, 1.4, 1.6, 1.28, 2.0, 2.56, 0.15, 0.17, 0.19, 0.2, 0.22, 0.24, 0.26, 0.28, 0.29, 0.31, 0.33, 0.35, 0.37, 0.38, 0.4, 0.42, 0.44, 0.46, 0.47, 0.49, 0.03, 0.09, 0.15, 0.21, 0.27, 0.33, 0.39, 0.45, 0.51, 0.57, 0.63, 0.69, 5e-08, 1e-07, 1e-06, 1e-05, 0.0001, 0.001, 0.01, 0.02, 0.023]

# %%
for eta in etas:
    #eta = eta0 * (2**count)
    loc = "PGD/LeNet5_relu_"+str(eta)
    # !python main.py -b 64 -n LeNet5 -a relu -l $eta -g 0
    # !python adv_PGD.py -n LeNet5 -a relu -l $eta -f $loc -g 0
    # !python main.py -b 64 -n LeNet5 -a relu -l $eta -r2 -f $loc -g 0
# Out:
# 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.30, err 0.84 | val loss 2.30, err 0.90 | adv loss 2.31, err 0.91
# ep 2/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.90 | adv loss 2.31, err 0.91
# ep 3/10: train loss 2.30, err 0.84 | val loss 2.30, err 0.90 | adv loss 2.31, err 0.91
# ep 4/10: train loss 2.31, err 0.97 | val loss 2.30, err 0.90 | adv loss 2.31, err 0.91
# ep 5/10: train loss 2.30, err 0.97 | val loss 2.30, err 0.90 | adv loss 2.31, err 0.91
# ep 6/10: train loss 2.31, err 0.94 | val loss 2.30, err 0.90 | adv loss 2.31, err 0.91
# ep 7/10: train loss 2.31, err 0.97 | val loss 2.30, err 0.90 | adv loss 2.31, err 0.91
# ep 8/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.90 | adv loss 2.31, err 0.91
# ep 9/10: train loss 2.30, err 0.75 | val loss 2.30, err 0.90 | adv loss 2.31, err 0.91
# ep 10/10: train loss 2.29, err 0.88 | val loss 2.30, err 0.90 | adv loss 2.31, err 0.91
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
#
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : relu, learning_rate -> <class 'float'> : 0.0001, round -> <class 'int'> : 1
# cuda:0
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.30, err 0.84 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 2/10: train loss 2.31, err 0.91 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 3/10: train loss 2.30, err 0.88 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 4/10: train loss 2.30, err 0.84 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 5/10: train loss 2.30, err 1.00 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 6/10: train loss 2.29, err 0.88 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 7/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 8/10: train loss 2.29, err 0.84 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 9/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.90 | adv loss -1.00, err -1.00
# ep 10/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.91 | adv loss -1.00, err -1.00
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
# network -> <class 'str'> : LeNet5, activation -> <class 'str'> : relu, learning_rate -> <class 'float'> : 0.0001, adv_folder-> <class 'str'> : PGD/LeNet5_relu_0.0001
# cuda:0
# loading model at ./model_statedicts/mnist_LeNet5_relu_0.0001.pth
# ==> full_val has 10000 images
# l:  (8000, 1, 28, 28) (8000,)
# l2:  torch.Size([8000, 1, 28, 28]) torch.Size([8000])
# mkdir: cannot create directory ‘./PGD’: File exists
#  Progress 8000 / 8000
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : relu, learning_rate -> <class 'float'> : 0.0001, round -> <class 'int'> : 2
# cuda:0
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.30, err 0.84 | val loss 2.30, err 0.90 | adv loss 2.31, err 0.91
# ep 2/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.90 | adv loss 2.31, err 0.91
# ep 3/10: train loss 2.30, err 0.84 | val loss 2.30, err 0.90 | adv loss 2.31, err 0.91
# ep 4/10: train loss 2.31, err 0.97 | val loss 2.30, err 0.90 | adv loss 2.31, err 0.91
# ep 5/10: train loss 2.30, err 0.97 | val loss 2.30, err 0.90 | adv loss 2.31, err 0.92
# ep 6/10: train loss 2.31, err 0.94 | val loss 2.30, err 0.90 | adv loss 2.31, err 0.92
# ep 7/10: train loss 2.31, err 0.97 | val loss 2.30, err 0.90 | adv loss 2.31, err 0.93
# ep 8/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.90 | adv loss 2.31, err 0.96
# ep 9/10: train loss 2.30, err 0.75 | val loss 2.30, err 0.90 | adv loss 2.31, err 0.98
# ep 10/10: train loss 2.29, err 0.88 | val loss 2.30, err 0.91 | adv loss 2.31, err 1.00
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
#
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : relu, learning_rate -> <class 'float'> : 0.001, round -> <class 'int'> : 1
# cuda:0
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.30, err 0.84 | val loss 2.30, err 0.91 | adv loss -1.00, err -1.00
# ep 2/10: train loss 2.31, err 0.91 | val loss 2.30, err 0.89 | adv loss -1.00, err -1.00
# ep 3/10: train loss 2.29, err 0.84 | val loss 2.30, err 0.89 | adv loss -1.00, err -1.00
# ep 4/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.89 | adv loss -1.00, err -1.00
# ep 5/10: train loss 2.29, err 0.81 | val loss 2.30, err 0.89 | adv loss -1.00, err -1.00
# ep 6/10: train loss 2.29, err 0.75 | val loss 2.30, err 0.89 | adv loss -1.00, err -1.00
# ep 7/10: train loss 2.29, err 0.84 | val loss 2.30, err 0.89 | adv loss -1.00, err -1.00
# ep 8/10: train loss 2.29, err 0.88 | val loss 2.30, err 0.89 | adv loss -1.00, err -1.00
# ep 9/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.89 | adv loss -1.00, err -1.00
# ep 10/10: train loss 2.29, err 0.84 | val loss 2.30, err 0.89 | adv loss -1.00, err -1.00
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
# network -> <class 'str'> : LeNet5, activation -> <class 'str'> : relu, learning_rate -> <class 'float'> : 0.001, adv_folder-> <class 'str'> : PGD/LeNet5_relu_0.001
# cuda:0
# loading model at ./model_statedicts/mnist_LeNet5_relu_0.001.pth
# ==> full_val has 10000 images
# l:  (8000, 1, 28, 28) (8000,)
# l2:  torch.Size([8000, 1, 28, 28]) torch.Size([8000])
# mkdir: cannot create directory ‘./PGD’: File exists
#  Progress 8000 / 8000
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : relu, learning_rate -> <class 'float'> : 0.001, round -> <class 'int'> : 2
# cuda:0
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.30, err 0.84 | val loss 2.30, err 0.91 | adv loss 2.31, err 0.96
# ep 2/10: train loss 2.30, err 0.75 | val loss 2.30, err 0.89 | adv loss 2.31, err 0.90
# ep 3/10: train loss 2.30, err 0.97 | val loss 2.30, err 0.89 | adv loss 2.31, err 0.90
# ep 4/10: train loss 2.30, err 0.88 | val loss 2.30, err 0.89 | adv loss 2.31, err 0.90
# ep 5/10: train loss 2.30, err 0.81 | val loss 2.30, err 0.89 | adv loss 2.31, err 0.90
# ep 6/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.89 | adv loss 2.31, err 0.90
# ep 7/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.89 | adv loss 2.31, err 0.90
# ep 8/10: train loss 2.30, err 0.91 | val loss 2.30, err 0.89 | adv loss 2.31, err 0.90
# ep 9/10: train loss 2.30, err 0.97 | val loss 2.30, err 0.89 | adv loss 2.31, err 0.90
# ep 10/10: train loss 2.28, err 0.78 | val loss 2.30, err 0.89 | adv loss 2.31, err 0.90
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
#
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : relu, learning_rate -> <class 'float'> : 0.01, round -> <class 'int'> : 1
# cuda:0
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.89 | adv loss -1.00, err -1.00
# ep 2/10: train loss 2.10, err 0.78 | val loss 2.08, err 0.70 | adv loss -1.00, err -1.00
# ep 3/10: train loss 0.64, err 0.12 | val loss 0.82, err 0.28 | adv loss -1.00, err -1.00
# ep 4/10: train loss 0.40, err 0.16 | val loss 0.46, err 0.16 | adv loss -1.00, err -1.00
# ep 5/10: train loss 0.10, err 0.03 | val loss 0.18, err 0.05 | adv loss -1.00, err -1.00
# ep 6/10: train loss 0.13, err 0.06 | val loss 0.15, err 0.04 | adv loss -1.00, err -1.00
# ep 7/10: train loss 0.07, err 0.03 | val loss 0.10, err 0.03 | adv loss -1.00, err -1.00
# ep 8/10: train loss 0.08, err 0.03 | val loss 0.09, err 0.03 | adv loss -1.00, err -1.00
# ep 9/10: train loss 0.11, err 0.03 | val loss 0.08, err 0.03 | adv loss -1.00, err -1.00
# ep 10/10: train loss 0.07, err 0.03 | val loss 0.07, err 0.02 | adv loss -1.00, err -1.00
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
# network -> <class 'str'> : LeNet5, activation -> <class 'str'> : relu, learning_rate -> <class 'float'> : 0.01, adv_folder-> <class 'str'> : PGD/LeNet5_relu_0.01
# cuda:0
# loading model at ./model_statedicts/mnist_LeNet5_relu_0.01.pth
# ==> full_val has 10000 images
# l:  (8000, 1, 28, 28) (8000,)
# l2:  torch.Size([8000, 1, 28, 28]) torch.Size([8000])
# mkdir: cannot create directory ‘./PGD’: File exists
# mkdir: cannot create directory ‘PGD/LeNet5_relu_0.01’: File exists
# mkdir: cannot create directory ‘0000’: File exists
# mkdir: cannot create directory ‘0001’: File exists
# mkdir: cannot create directory ‘0002’: File exists
# mkdir: cannot create directory ‘0003’: File exists
# mkdir: cannot create directory ‘0004’: File exists
# mkdir: cannot create directory ‘0005’: File exists
# mkdir: cannot create directory ‘0006’: File exists
# mkdir: cannot create directory ‘0007’: File exists
# mkdir: cannot create directory ‘0008’: File exists
# mkdir: cannot create directory ‘0009’: File exists
#  Progress 8000 / 8000
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : relu, learning_rate -> <class 'float'> : 0.01, round -> <class 'int'> : 2
# cuda:0
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.30, err 0.94 | val loss 2.30, err 0.89 | adv loss 2.30, err 0.90
# ep 2/10: train loss 2.02, err 0.59 | val loss 2.07, err 0.71 | adv loss 2.16, err 0.76
# ep 3/10: train loss 0.63, err 0.16 | val loss 0.70, err 0.23 | adv loss 1.89, err 0.64
# ep 4/10: train loss 0.46, err 0.16 | val loss 0.46, err 0.16 | adv loss 1.52, err 0.49
# ep 5/10: train loss 0.40, err 0.09 | val loss 0.42, err 0.15 | adv loss 1.67, err 0.55
# ep 6/10: train loss 0.39, err 0.16 | val loss 0.36, err 0.13 | adv loss 1.93, err 0.59
# ep 7/10: train loss 0.12, err 0.03 | val loss 0.33, err 0.13 | adv loss 2.36, err 0.64
# ep 8/10: train loss 0.07, err 0.03 | val loss 0.10, err 0.03 | adv loss 2.27, err 0.60
# ep 9/10: train loss 0.14, err 0.06 | val loss 0.10, err 0.03 | adv loss 2.25, err 0.59
# ep 10/10: train loss 0.09, err 0.06 | val loss 0.11, err 0.03 | adv loss 2.22, err 0.59
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
#
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : relu, learning_rate -> <class 'float'> : 0.02, round -> <class 'int'> : 1
# cuda:0
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.19, err 0.75 | val loss 2.08, err 0.71 | adv loss -1.00, err -1.00
# ep 2/10: train loss 0.58, err 0.19 | val loss 0.52, err 0.18 | adv loss -1.00, err -1.00
# ep 3/10: train loss 0.12, err 0.03 | val loss 0.14, err 0.04 | adv loss -1.00, err -1.00
# ep 4/10: train loss 0.11, err 0.06 | val loss 0.09, err 0.03 | adv loss -1.00, err -1.00
# ep 5/10: train loss 0.05, err 0.03 | val loss 0.08, err 0.03 | adv loss -1.00, err -1.00
# ep 6/10: train loss 0.08, err 0.03 | val loss 0.07, err 0.02 | adv loss -1.00, err -1.00
# ep 7/10: train loss 0.01, err 0.00 | val loss 0.06, err 0.02 | adv loss -1.00, err -1.00
# ep 8/10: train loss 0.04, err 0.00 | val loss 0.05, err 0.02 | adv loss -1.00, err -1.00
# ep 9/10: train loss 0.02, err 0.00 | val loss 0.05, err 0.01 | adv loss -1.00, err -1.00
# ep 10/10: train loss 0.05, err 0.03 | val loss 0.05, err 0.02 | adv loss -1.00, err -1.00
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
# network -> <class 'str'> : LeNet5, activation -> <class 'str'> : relu, learning_rate -> <class 'float'> : 0.02, adv_folder-> <class 'str'> : PGD/LeNet5_relu_0.02
# cuda:0
# loading model at ./model_statedicts/mnist_LeNet5_relu_0.02.pth
# ==> full_val has 10000 images
# l:  (8000, 1, 28, 28) (8000,)
# l2:  torch.Size([8000, 1, 28, 28]) torch.Size([8000])
# mkdir: cannot create directory ‘./PGD’: File exists
# mkdir: cannot create directory ‘PGD/LeNet5_relu_0.02’: File exists
# mkdir: cannot create directory ‘0000’: File exists
# mkdir: cannot create directory ‘0001’: File exists
# mkdir: cannot create directory ‘0002’: File exists
# mkdir: cannot create directory ‘0003’: File exists
# mkdir: cannot create directory ‘0004’: File exists
# mkdir: cannot create directory ‘0005’: File exists
# mkdir: cannot create directory ‘0006’: File exists
# mkdir: cannot create directory ‘0007’: File exists
# mkdir: cannot create directory ‘0008’: File exists
# mkdir: cannot create directory ‘0009’: File exists
#  Progress 8000 / 8000
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : relu, learning_rate -> <class 'float'> : 0.02, round -> <class 'int'> : 2
# cuda:0
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 2.19, err 0.75 | val loss 2.08, err 0.71 | adv loss 2.16, err 0.73
# ep 2/10: train loss 0.21, err 0.09 | val loss 0.46, err 0.16 | adv loss 1.27, err 0.42
# ep 3/10: train loss 0.06, err 0.00 | val loss 0.12, err 0.04 | adv loss 1.20, err 0.41
# ep 4/10: train loss 0.17, err 0.06 | val loss 0.10, err 0.03 | adv loss 1.45, err 0.45
# ep 5/10: train loss 0.21, err 0.03 | val loss 0.08, err 0.03 | adv loss 1.36, err 0.49
# ep 6/10: train loss 0.01, err 0.00 | val loss 0.06, err 0.02 | adv loss 1.53, err 0.52
# ep 7/10: train loss 0.03, err 0.00 | val loss 0.06, err 0.02 | adv loss 1.77, err 0.56
# ep 8/10: train loss 0.03, err 0.00 | val loss 0.05, err 0.02 | adv loss 1.72, err 0.57
# ep 9/10: train loss 0.03, err 0.00 | val loss 0.05, err 0.02 | adv loss 2.01, err 0.59
# ep 10/10: train loss 0.09, err 0.03 | val loss 0.06, err 0.02 | adv loss 1.88, err 0.60
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
#
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : relu, learning_rate -> <class 'float'> : 0.023, round -> <class 'int'> : 1
# cuda:0
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 1.67, err 0.47 | val loss 1.49, err 0.53 | adv loss -1.00, err -1.00
# ep 2/10: train loss 0.55, err 0.19 | val loss 0.47, err 0.17 | adv loss -1.00, err -1.00
# ep 3/10: train loss 0.08, err 0.03 | val loss 0.11, err 0.03 | adv loss -1.00, err -1.00
# ep 4/10: train loss 0.08, err 0.06 | val loss 0.08, err 0.02 | adv loss -1.00, err -1.00
# ep 5/10: train loss 0.04, err 0.03 | val loss 0.07, err 0.02 | adv loss -1.00, err -1.00
# ep 6/10: train loss 0.08, err 0.03 | val loss 0.07, err 0.02 | adv loss -1.00, err -1.00
# ep 7/10: train loss 0.01, err 0.00 | val loss 0.06, err 0.02 | adv loss -1.00, err -1.00
# ep 8/10: train loss 0.04, err 0.03 | val loss 0.05, err 0.02 | adv loss -1.00, err -1.00
# ep 9/10: train loss 0.02, err 0.00 | val loss 0.05, err 0.01 | adv loss -1.00, err -1.00
# ep 10/10: train loss 0.03, err 0.00 | val loss 0.04, err 0.01 | adv loss -1.00, err -1.00
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists
# network -> <class 'str'> : LeNet5, activation -> <class 'str'> : relu, learning_rate -> <class 'float'> : 0.023, adv_folder-> <class 'str'> : PGD/LeNet5_relu_0.023
# cuda:0
# loading model at ./model_statedicts/mnist_LeNet5_relu_0.023.pth
# ==> full_val has 10000 images
# l:  (8000, 1, 28, 28) (8000,)
# l2:  torch.Size([8000, 1, 28, 28]) torch.Size([8000])
# mkdir: cannot create directory ‘./PGD’: File exists
#  Progress 8000 / 8000
#  displaying options as <name> -> <type> : <value>
# batch_size -> <class 'int'> : 64, network -> <class 'str'> : LeNet5, activation -> <class 'str'> : relu, learning_rate -> <class 'float'> : 0.023, round -> <class 'int'> : 2
# cuda:0
# Trainset (original MNIST) like torch.Size([60000, 28, 28]) with minimum 0.0 and maximum 1.0
# Valset (original MNIST) like torch.Size([10000, 28, 28]) with minimum 0.0 and maximum 1.0
# <class 'network.Net'>
# ep 1/10: train loss 1.67, err 0.47 | val loss 1.49, err 0.53 | adv loss 1.81, err 0.64
# ep 2/10: train loss 0.17, err 0.09 | val loss 0.41, err 0.15 | adv loss 1.19, err 0.39
# ep 3/10: train loss 0.04, err 0.00 | val loss 0.10, err 0.03 | adv loss 1.13, err 0.39
# ep 4/10: train loss 0.17, err 0.06 | val loss 0.09, err 0.03 | adv loss 1.42, err 0.44
# ep 5/10: train loss 0.20, err 0.03 | val loss 0.08, err 0.03 | adv loss 1.34, err 0.48
# ep 6/10: train loss 0.01, err 0.00 | val loss 0.06, err 0.02 | adv loss 1.48, err 0.51
# ep 7/10: train loss 0.02, err 0.00 | val loss 0.05, err 0.02 | adv loss 1.77, err 0.56
# ep 8/10: train loss 0.03, err 0.00 | val loss 0.05, err 0.02 | adv loss 1.66, err 0.55
# ep 9/10: train loss 0.02, err 0.00 | val loss 0.05, err 0.02 | adv loss 1.95, err 0.57
# ep 10/10: train loss 0.10, err 0.03 | val loss 0.06, err 0.02 | adv loss 1.83, err 0.58
# mkdir: cannot create directory ‘./np_data’: File exists
# mkdir: cannot create directory ‘./np_data/PGD’: File exists
# mkdir: cannot create directory ‘./np_data/CW’: File exists
# mkdir: cannot create directory ‘./model_statedicts’: File exists

# %%
# PGD relu plot
import numpy as np
from plot import lr_plot

unsorted_etas = [0.1, 0.01, 0.2, 0.02, 0.3, 0.4, 0.04, 0.5, 0.05, 0.6, 0.7, 0.007, 0.8, 0.08, 0.9, 0.014, 0.16, 0.028, 0.32, 0.0035, 0.056, 0.64, 0.112, 0.224, 0.448, 1.0, 1.1, 1.2, 1.3, 1.4, 1.6, 1.28, 2.0, 2.56] + np.round(np.arange(0.15, 0.5, 0.018), 2).tolist() + [0.00000005, 0.0000001, 0.000001, 0.00001, 0.0001, 0.001, 0.023] + np.round(np.arange(0.03, 0.7, 0.06), 2).tolist() + [0.00000005, 0.0000001, 0.000001, 0.00001, 0.0001, 0.001, 0.01, 0.02, 0.023]

etas = sorted(unsorted_etas, reverse=False)
list = []
for eta in etas:
    list.append("PGD/LeNet5_relu_{}".format(eta))
lr_plot(list, etas)

# %%
from plot import get_adv_err, get_val_err
print(etas)
print('2/L: val acc {} | adv acc {}'.format(1-get_val_err('PGD/LeNet5_relu_0.63'), 1-get_adv_err('PGD/LeNet5_relu_0.63')))
print('1/L: val acc {} | adv acc {}'.format(1-get_val_err('PGD/LeNet5_relu_0.31'), 1-get_adv_err('PGD/LeNet5_relu_0.31')))
# Out:
# [5e-08, 5e-08, 1e-07, 1e-07, 1e-06, 1e-06, 1e-05, 1e-05, 0.0001, 0.0001, 0.001, 0.001, 0.0035, 0.007, 0.01, 0.01, 0.014, 0.02, 0.02, 0.023, 0.023, 0.028, 0.03, 0.04, 0.05, 0.056, 0.08, 0.09, 0.1, 0.112, 0.15, 0.15, 0.16, 0.17, 0.19, 0.2, 0.2, 0.21, 0.22, 0.224, 0.24, 0.26, 0.27, 0.28, 0.29, 0.3, 0.31, 0.32, 0.33, 0.33, 0.35, 0.37, 0.38, 0.39, 0.4, 0.4, 0.42, 0.44, 0.448, 0.45, 0.46, 0.47, 0.49, 0.5, 0.51, 0.57, 0.6, 0.63, 0.64, 0.69, 0.7, 0.8, 0.9, 1.0, 1.1, 1.2, 1.28, 1.3, 1.4, 1.6, 2.0, 2.56]
# 2/L: val acc 0.9887000005692244 | adv acc 0.7306249737739563
# 1/L: val acc 0.9883000003173947 | adv acc 0.7193749845027924
